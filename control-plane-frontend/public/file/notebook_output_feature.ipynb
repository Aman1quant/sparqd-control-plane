# %%
#username = "dat03_tiamut_access"
#password = dbutils.secrets.get(scope="v8-mongo-connectionString", key="password")

# %%
from datetime import date, timedelta
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.functions import concat, split, col, lit, when, from_unixtime, to_date, posexplode, from_utc_timestamp
from pyspark.sql.types import StringType, ArrayType, StructType, BooleanType, IntegerType, DoubleType, TimestampType, DateType
import re, os
from pyspark.sql import Row
from datetime import datetime, timedelta
from pyspark.sql.types import *
import pyspark.sql.functions as F
from pyspark.sql.utils import AnalysisException
from delta.tables import DeltaTable
import logging
from pyspark.sql.functions import col, current_timestamp
from pyspark.sql.functions import (
    col, when, size, lit, expr, broadcast
)

# %%
df = spark.table("v2.raw.raw_precal_prod").filter(
    (col("update_date") >= to_timestamp(lit("2025-07-03 00:00:00+00:00"))) &
    (col("update_date") <  to_timestamp(lit("2025-07-04 00:00:00+00:00")))
)

display(df)
# df = df.filter(col("currency") == "THB")
# df = df.filter(F.substring(F.col("create_date"),1,10).isin("2025-07-02","2025-07-01"))
# windowSpec = Window.partitionBy("pre_cal_id").orderBy(F.desc("create_date"))
# df = df.select("*", F.row_number().over(windowSpec).alias("row_number")).filter(F.col("row_number") == 1)
# df = df.groupBy(F.substring(F.col("create_date"),1,10)) \
#         .agg(F.count("*").alias("count"), \
#             sum("bet_amt").alias("sum_bet_amt"))
# df.show(truncate=False, vertical=False)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
